# %%
# -*- coding: utf-8 -*-
from keras.optimizers import Adam
import pandas as pd
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import to_categorical as labelEncoding

from sklearn.metrics import (confusion_matrix,  matthews_corrcoef, precision_score, roc_curve, auc)
from sklearn.model_selection import KFold
from model import ourmodel
import numpy as np
from smote import datapro

# %%
my_seed = 42
np.random.seed(my_seed)
import random

random.seed(my_seed)
import tensorflow as tf

tf.random.set_seed(my_seed)
model = ourmodel()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 49, 96)]     0           []
#
#  conv1d (Conv1D)                (None, 49, 128)      36992       ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 49, 128)      61568       ['input_1[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 49, 128)      86144       ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 49, 128)     512         ['conv1d[0][0]']
#  alization)
#
#  batch_normalization_1 (BatchNo  (None, 49, 128)     512         ['conv1d_1[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 49, 128)     512         ['conv1d_2[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 49, 128)      0           ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 49, 128)      0           ['batch_normalization_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 49, 128)      0           ['batch_normalization_2[0][0]']
#
#  add (Add)                      (None, 49, 128)      0           ['dropout[0][0]',
#                                                                   'dropout_1[0][0]',
#                                                                   'dropout_2[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 47, 128)      0           ['add[0][0]']
#
#  dropout_3 (Dropout)            (None, 47, 128)      0           ['max_pooling1d[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 45, 256)      98560       ['dropout_3[0][0]']
#
#  bidirectional (Bidirectional)  (None, 45, 256)      394240      ['conv1d_3[0][0]']
#
#  add_1 (Add)                    (None, 45, 256)      0           ['bidirectional[0][0]',
#                                                                   'conv1d_3[0][0]']
#
#  flatten (Flatten)              (None, 11520)        0           ['add_1[0][0]']
#
#  FC3 (Dense)                    (None, 128)          1474688     ['flatten[0][0]']
#
#  FC2 (Dense)                    (None, 64)           8256        ['FC3[0][0]']
#
#  dropout_4 (Dropout)            (None, 64)           0           ['FC2[0][0]']
#
#  FC4 (Dense)                    (None, 32)           2080        ['dropout_4[0][0]']
#
#  Output (Dense)                 (None, 2)            66          ['FC4[0][0]']
#
# ==================================================================================================
# Total params: 2,164,130
# Trainable params: 2,163,362
# Non-trainable params: 768
# __________________________________________________________________________________________________

# %%
data1 = np.load('Example data/example_X.npz')
X1 = data1['x_train']
X2 = data1['x_test']

y_1 = pd.read_csv('Example data/exampley_train.csv').to_numpy()
y_2 = pd.read_csv('Example data/exampley_test.csv').to_numpy()
y2 = labelEncoding(y_2, dtype=int)
X1, y_1 = datapro(X1, y_1)
y1 = labelEncoding(y_1, dtype=int)

# %%
if __name__ == '__main__':
    config = tf.compat.v1.ConfigProto()

    config.gpu_options.allow_growth = True

    session = tf.compat.v1.Session(config=config)
    # set epoch and batch_size
    setEpochNumber = 100  # 50 100 150
    setBatchSizeNumber = 32
    ####################################################

    cv = KFold(n_splits=5, shuffle=True, random_state=42)

    Accuracy = []
    Sensitivity = []
    Specificity = []
    Precision = []
    MCC = []

    # ROC Curve:
    fig1 = plt.figure(figsize=[12, 12])

    TPR = []
    meanFPR = np.linspace(0, 1, 100)

    i = 1

    names = ['first']
    name = names[0]
    nn = 1

    for train, test in cv.split(y1):

        # Compile Model:
        model = ourmodel()
        model.compile(optimizer=Adam(learning_rate=0.0001),
                      loss='categorical_crossentropy',
                      metrics=['accuracy'])

        filepath = 'ToxMSRC/%sModel%d.tf' % (name, nn)

        checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True,
                                     save_weights_only=True, mode='max')
        callbacks_list = [checkpoint]
        back = EarlyStopping(monitor='val_accuracy', patience=20, verbose=1, mode='auto')
        # Run Model:
        results = model.fit(x=[X1[train, :]],
                            y=y1[train, :],
                            validation_data=([X1[test, :]], y1[test, :]),
                            batch_size=setBatchSizeNumber, epochs=setEpochNumber,  # batch_size???
                            verbose=1,
                            callbacks=[callbacks_list, back])
        model.save('ToxMSRC/%sModel%d.h5' % (name, nn))

        nn += 1
        accuracy = model.evaluate(x=[X2], y=y2)
        Accuracy.append(accuracy[1])

        # Performance Metices:
        Yactual = y_2
        Yp = model.predict([X2])
        v = Yp
        Yp = Yp.argmax(axis=1)

        CM = confusion_matrix(y_pred=Yp, y_true=Yactual)
        TN, FP, FN, TP = CM.ravel()

        MCC.append(matthews_corrcoef(y_true=Yactual, y_pred=Yp))
        Sensitivity.append(TP / (TP + FN))
        Specificity.append(TN / (TN + FP))
        Precision.append(precision_score(y_true=Yactual, y_pred=Yp))

        # ROC Curve
        fpr, tpr, _ = roc_curve(Yactual, v[:, 1])
        TPR.append(np.interp(meanFPR, fpr, tpr))
        rocauc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, alpha=0.3, label='ROC fold %d (AUC = %0.4f)' % (i, rocauc))
        i = i + 1
        # plt.legend()
        # plt.show()

        print('AUC:', rocauc)
        print('Accuracy:', Accuracy)
        print('Sensitivity: ', Sensitivity)
        print('Specificity: ', Specificity)
        print('MCC:', MCC)
        print('Precision: ', Precision)
